# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.set_option('display.max_columns', None)
df = pd.read_csv('../../data/clean_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4
#       5 pd.set_option('display.max_columns', None)
# ----> 6 df = pd.read_csv('../../data/clean_data.csv')
#
# File c:\Users\amand\codeYou\dataAnalysis\capstone\gaming_mental_health_analysis\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\amand\codeYou\dataAnalysis\capstone\gaming_mental_health_analysis\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\amand\codeYou\dataAnalysis\capstone\gaming_mental_health_analysis\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\amand\codeYou\dataAnalysis\capstone\gaming_mental_health_analysis\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\amand\codeYou\dataAnalysis\capstone\gaming_mental_health_analysis\venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/clean_data.csv'

# %% [markdown]
# ## EDA
# ### EDA Initial questions
# - [x] What were the total scores for GAD, SWL, and SPIN? (histogram)
# - [x] How did reported hours played impact the GAD, SWL, and SPIN totals? (chart type?)
# - [x] What game(s) are played the most hours per week? (Bar chart)
# - [x] Do any factors seem to lead to high GAD, SWL, and SPIN totals? (Grouped bars; Console, Residence, Gender vs totals)
# - [ ] What most impacts hours played? (~~Scatter plots;~~ age, gender, residence, console vs hours played) stacked area line graph??
#
#
# Initial investigation of cleaned data

# %%
# df.info()
# df.describe()
df.head()
# Out:
#    Unnamed: 0  S. No.        Date  GAD1_Feeling_nervous  \
# 0           0       1  2015-02-17                     0
# 1           1       2  2015-02-17                     1
# 2           2       3  2015-02-17                     0
# 3           3       4  2015-02-17                     0
# 4           4       5  2015-02-17                     2
#
#    GAD2_Cant_stop_worrying  GAD3_Worrying_too_much  GAD4_Trouble_relaxing  \
# 0                        0                       0                      0
# 1                        2                       2                      2
# 2                        2                       2                      0
# 3                        0                       0                      0
# 4                        1                       2                      2
#
#    GAD5_Restless  GAD6_Easily_annoyed  GAD7_Feeling_afraid  \
# 0              1                    0                    0
# 1              0                    1                    0
# 2              0                    3                    1
# 3              0                    0                    0
# 4              2                    3                    2
#
#    GADE_Difficulty_in_life_num GADE_Difficulty_in_life  SWL1_Ideal_life  \
# 0                            0    Not difficult at all                3
# 1                            1      Somewhat difficult                3
# 2                            0    Not difficult at all                2
# 3                            0    Not difficult at all                2
# 4                            2          Very difficult                2
#
#    SWL2_Excellent_conditions  SWL3_Satisfied_with_life  SWL4_Met_wants  \
# 0                          5                         5               5
# 1                          5                         2               5
# 2                          6                         5               2
# 3                          5                         5               3
# 4                          2                         4               5
#
#    SWL5_Change_nothing    Game                 Platform  Hours  \
# 0                    5  Skyrim  Console (PS, Xbox, ...)     15
# 1                    1   Other                       PC      8
# 2                    2   Other                       PC      0
# 3                    2   Other                       PC     20
# 4                    1   Other  Console (PS, Xbox, ...)     20
#
#          Earnings    Why_play   League  Non_game_hours  SPIN1_Fear_authority  \
# 0  I play for fun  having fun  unknown               0                     1
# 1  I play for fun  having fun  unknown               2                     2
# 2  I play for fun  having fun  unknown               0                     1
# 3  I play for fun   improving  unknown               5                     2
# 4  I play for fun  having fun  unknown               1                     2
#
#    SPIN2_Distress_blushing  SPIN3_Fear_social_events  SPIN4_Avoid_strangers  \
# 0                        0                         0                      1
# 1                        1                         1                      3
# 2                        0                         1                      2
# 3                        0                         0                      1
# 4                        0                         0                      0
#
#    SPIN5_Fear_criticism  SPIN6_Avoid_embarrassment  SPIN7_Distress_sweating  \
# 0                     0                          0                        1
# 1                     2                          3                        1
# 2                     3                          4                        2
# 3                     3                          0                        0
# 4                     1                          0                        0
#
#    SPIN8_Avoid_parties  SPIN9_Avoid_attention  SPIN10_Fear_talking_strangers  \
# 0                    0                      0                              0
# 1                    3                      4                              0
# 2                    1                      0                              1
# 3                    0                      0                              0
# 4                    4                      2                              0
#
#    SPIN11_Avoid_giving_speeches  SPIN12_Avoid_criticism  \
# 0                             0                       0
# 1                             3                       0
# 2                             1                       3
# 3                             1                       3
# 4                             1                       0
#
#    SPIN13_Distress_heart  SPIN14_Fear_observation  SPIN15_Fear_embarrassment  \
# 0                      0                        1                          0
# 1                      1                        3                          3
# 2                      0                        2                          4
# 3                      0                        0                          1
# 4                      0                        0                          0
#
#    SPIN16_Avoid_authority  SPIN17_Distress_trembling  Narcissism  Gender  Age  \
# 0                       1                          0         1.0    Male   25
# 1                       1                          2         1.0    Male   41
# 2                       4                          2         4.0  Female   32
# 3                       0                          0         2.0    Male   28
# 4                       3                          0         1.0    Male   19
#
#                         Work                               Degree Reference  \
# 0  Unemployed / between jobs             Bachelor (or equivalent)    Reddit
# 1  Unemployed / between jobs             Bachelor (or equivalent)    Reddit
# 2                   Employed             Bachelor (or equivalent)    Reddit
# 3                   Employed             Bachelor (or equivalent)    Reddit
# 4                   Employed  High school diploma (or equivalent)    Reddit
#
#                                           Play_style  Accept  GAD_Total  \
# 0                                       Singleplayer  Accept          1
# 1              Multiplayer - online - with strangers  Accept          8
# 2                                       Singleplayer  Accept          8
# 3  Multiplayer - online - with online acquaintanc...  Accept          0
# 4              Multiplayer - online - with strangers  Accept         14
#
#    SWL_Total  SPIN_Total Residence_ISO3 Birthplace_ISO3
# 0         23           5            USA             USA
# 1         16          33            USA             USA
# 2         17          31            DEU             DEU
# 3         17          11            USA             USA
# 4         14          13            KOR             USA

# %% [markdown]
# ### Histograms
# - What is the distribution of test results for each test?
# - What is the distribution of hours spent gaming per week?
#
# - Why this chart type?
#   - A histogram shows allows for a quick glance to notice trends with this kind of data.
# - Conclusions:
#   - Hours > A significant amount report about 20 hours/week. **A boxplot may be helpful here**
#   - GAD (Generalized Anxiety Disorder) > Results skew towards lower anxiety
#   - SWL (Satisfaction With Life) > These results spread the whole spectrum. There is a curve peaking near neutral, with high numbers in both slightly dissatisfied and slightly satisfied.
#   - SPIN (Social Phobia Inventory) > Results show the majority have low to mid levels of social anxiety

# %%
plt.figure(figsize=(10,6))
plt.hist(
    df['GAD_Total'],
    bins=15,
    edgecolor='white'
)

plt.xlabel("Generalized Anxiety Disorder Assessment Score (0-21)")
plt.ylabel("Number of Survey Pariticpants")
plt.title("Distribution of GAD Scores", fontsize=16, pad=20)

# Save figure as image
# plt.savefig('plots/GAD_score_histogram.png')

plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(
    df['SWL_Total'],
    bins=17,
    edgecolor='white'
)

plt.xlabel("Satisfaction with Life Assessment (0-35)")
plt.ylabel("Number of Survey Pariticpants")
plt.title("Distribution of SWL Scores", fontsize=16, pad=20)

# Save figure as image
# plt.savefig('plots/SWL_score_histogram.png')

plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(
    df['SPIN_Total'],
    bins=25,
    edgecolor='white'
)

plt.xlabel("Social Phobia Inventory (SPIN) Assessment (0-35)")
plt.ylabel("Number of Survey Pariticpants")
plt.title("Distribution of SPIN Scores", fontsize=16, pad=20)

# Save figure as image
# plt.savefig('plots/SPIN_score_histogram.png')

plt.show()

# %%
df['Hours'].describe()
df['Hours'].value_counts()
# Out:
# Hours
# 20     2091
# 10     1244
# 30     1056
# 15      999
# 25      752
#        ...
# 46        1
# 160       1
# 110       1
# 112       1
# 96        1
# Name: count, Length: 81, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.hist(
    df['Hours'],
    bins=75,
    edgecolor='white'
)

plt.xlabel("Reported average hours spent gaming per week")
plt.ylabel("Number of Survey Pariticpants")
plt.title("Distribution of Average Weekly Hours Spent Gaming", fontsize=16, pad=20)

# Save figure as image
# plt.savefig('plots/Hours_per_week_histogram.png')

plt.show()

# %% [markdown]
# ### Bar Plot
# - How much average time was spent per week on the top-played games?
# - Why this chart type?
#   -  Bar plot was chosen to see these comparisons side-by-side
# - Conclusion: They're closer in duration than expected.
#
# What games are played for the longest duration? Games and Hours
# According to the survey paper, any games with fewer than 10 mentions were grouped under 'Other'

# %%
# df.value_counts('Game')

# %%
# groupby 'Game' and calculate the avg 'Hours'
avg_hrs_game = df.groupby('Game')['Hours'].mean().sort_values(ascending=False)
avg_hrs_game
# Out:
# Game
# Diablo 3               28.675000
# World of Warcraft      26.211268
# Counter Strike         25.387324
# Guild Wars 2           24.848485
# Skyrim                 23.304348
# Other                  22.108197
# League of Legends      21.429955
# Heroes of the Storm    20.405405
# Destiny                19.555556
# Hearthstone            16.602273
# Starcraft 2            16.511551
# Name: Hours, dtype: float64

# %%
plt.bar(avg_hrs_game.index, avg_hrs_game.values)

plt.xlabel('Game most played by participant')
plt.ylabel('Average hours per week spent gaming')
plt.title('Most popular games vs avg time spent gaming per week')
plt.xticks(rotation=-45, ha='left')

plt.tight_layout()
# Save figure as image
# plt.savefig('plots/Pop_game_hours_barplot.png')

plt.show()

# %% [markdown]
# ### Grouped Bar Charts
# - How do these relate to the GAD/SWL/SPIN scores?
#   - [x] gender
#   - [x] platform
#   - [x] residence (top 5 countries)
#   - [x] age (binned)
# - Grouped Bar chart selected to easily compare the average results of the three tests with the above categories in one spot.
#   - **gender** > GAD was slightly higher in 'Other' gender category and SWL was slightly lower. Males scored significantly lower on their SPIN assessments.
#   - **platform** > Smartphone/tablet users scored higher on both SPIN and GAD assessments
#   - **residence** (top 5 countries) > Gamers in the UK had slightly higher GAD and SPIN results and lower SWL. (lowest mental health at a glance)
#   - **age** (binned) > slight decrease in SPIN score as age increased, other scores were about the same

# %% [markdown]
# #### Gender / Scores Grouped Bar Chart

# %%
# Reference: https://www.geeksforgeeks.org/python/create-a-grouped-bar-plot-in-matplotlib/

x = np.arange(3)
gender_GAD_scores = df.groupby('Gender')['GAD_Total'].mean() 
gender_SWL_scores = df.groupby('Gender')['SWL_Total'].mean()
gender_SPIN_scores = df.groupby('Gender')['SPIN_Total'].mean()
width=.2 

plt.bar(x-0.2, gender_GAD_scores, width, color='royalblue')
plt.bar(x, gender_SWL_scores, width, color='turquoise')
plt.bar(x+0.2, gender_SPIN_scores, width, color='limegreen')

plt.xticks(x, ['Female', 'Male', 'Other'])
plt.xlabel('Gender')
plt.ylabel('Average Score')
plt.legend(['GAD', 'SWL', 'SPIN'])
plt.title('Gender and Average Test Scores')

# Save figure as image
# plt.savefig('plots/Gender_scores_grouped_bar_chart.png')

plt.show()

# %%
# Testing to see which axis is what

# plt.bar(x, gender_GAD_scores, width, color='magenta')

# plt.xticks(x, ['Female', 'Male', 'Other'])
# plt.xlabel('Gender')
# plt.ylabel('Score')
# # plt.legend(['Female', 'Male', 'Other'])

# plt.show()

# %% [markdown]
# #### Platform / Scores Grouped Bar Chart

# %%
df['Platform'].value_counts()
# Out:
# Platform
# PC                         11922
# Console (PS, Xbox, ...)      204
# Smartphone / Tablet           19
# Name: count, dtype: int64

# %%
x = np.arange(3)
platform_GAD_scores = df.groupby('Platform')['GAD_Total'].mean() 
platform_SWL_scores = df.groupby('Platform')['SWL_Total'].mean()
platform_SPIN_scores = df.groupby('Platform')['SPIN_Total'].mean()
width=.2 

plt.bar(x-0.2, platform_GAD_scores, width, color='royalblue')
plt.bar(x, platform_SWL_scores, width, color='turquoise')
plt.bar(x+0.2, platform_SPIN_scores, width, color='limegreen')

plt.xticks(x, ['PC', 'Console', 'Smartphone/Tablet'])
plt.xlabel('Gaming platform')
plt.ylabel('Average Score')
plt.legend(['GAD', 'SWL', 'SPIN'])
plt.title('Gaming Platform and Average Test Scores')

# Save figure as image
# plt.savefig('plots/Platform_scores_grouped_bar_chart.png')

plt.show()

# %% [markdown]
# #### Residence / Scores Grouped Bar Chart

# %%
df['Residence_ISO3'].value_counts().head(10)
# Out:
# Residence_ISO3
# USA    4172
# DEU    1274
# GBR     904
# CAN     898
# NLD     460
# FRA     355
# SWE     327
# BRA     232
# POL     224
# DNK     219
# Name: count, dtype: int64

# %%
# Reference for selecting top 5 countries: https://stackoverflow.com/questions/56920927/selecting-top-n-rows-from-a-categorycolumn-in-a-pandas-dataframe-and-perform-c

# top_countries_GAD = df.groupby('Residence_ISO3',as_index=False).apply(lambda x: x.nlargest(5,'GAD_Total')).mean()
# top_countries_GAD

# %% [markdown]
# Make new df with just the top 5 countries represented

# %%
top10_countries = df['Residence_ISO3'].value_counts().head(5).index

top10_countries_df = df[df['Residence_ISO3'].isin(top10_countries)]
top10_countries_df['Residence_ISO3'].value_counts()
# Out:
# Residence_ISO3
# USA    4172
# DEU    1274
# GBR     904
# CAN     898
# NLD     460
# Name: count, dtype: int64

# %%
x = np.arange(5)
residence_GAD_scores = top10_countries_df.groupby('Residence_ISO3')['GAD_Total'].mean() 
residence_SWL_scores = top10_countries_df.groupby('Residence_ISO3')['SWL_Total'].mean()
residence_SPIN_scores = top10_countries_df.groupby('Residence_ISO3')['SPIN_Total'].mean()
width=.2 

plt.bar(x-0.2, residence_GAD_scores, width, color='royalblue')
plt.bar(x, residence_SWL_scores, width, color='turquoise')
plt.bar(x+0.2, residence_SPIN_scores, width, color='limegreen')

plt.xticks(x, ['USA', 'Germany', 'United Kingdom', 'Canada', 'Netherlands'])
plt.xlabel('Residence')
plt.ylabel('Average Score')
plt.legend(['GAD', 'SWL', 'SPIN'])
plt.title('Residence and Average Test Scores')

# Save figure as image
# plt.savefig('plots/Residence_scores_grouped_bar_chart.png')

plt.show()

# %% [markdown]
# #### Age / Scores Grouped Bar Chart

# %%
# top10_countries = df['Residence_ISO3'].value_counts().head(5).index

# top10_countries_df = df[df['Residence_ISO3'].isin(top10_countries)]
# top10_countries_df['Residence_ISO3'].value_counts()

df['Age'].describe()
# Out:
# count    12145.000000
# mean        20.936846
# std          3.252856
# min         18.000000
# 25%         18.000000
# 50%         20.000000
# 75%         22.000000
# max         56.000000
# Name: Age, dtype: float64

# %%
# Bin ages (Reference: https://www.geeksforgeeks.org/python/pandas-cut-method-in-python/)
bins = [18, 20, 22, 26, 60]
labels = ['18-19', '20-22','23-25', '26+']

df['Age_binned'] = pd.cut(df['Age'], bins=bins, labels=labels)

col_to_move = df.pop('Age_binned')
df.insert(43, 'Age_binned', col_to_move)

df.head()
# df.info()
# Out:
#    Unnamed: 0  S. No.        Date  GAD1_Feeling_nervous  \
# 0           0       1  2015-02-17                     0
# 1           1       2  2015-02-17                     1
# 2           2       3  2015-02-17                     0
# 3           3       4  2015-02-17                     0
# 4           4       5  2015-02-17                     2
#
#    GAD2_Cant_stop_worrying  GAD3_Worrying_too_much  GAD4_Trouble_relaxing  \
# 0                        0                       0                      0
# 1                        2                       2                      2
# 2                        2                       2                      0
# 3                        0                       0                      0
# 4                        1                       2                      2
#
#    GAD5_Restless  GAD6_Easily_annoyed  GAD7_Feeling_afraid  \
# 0              1                    0                    0
# 1              0                    1                    0
# 2              0                    3                    1
# 3              0                    0                    0
# 4              2                    3                    2
#
#    GADE_Difficulty_in_life_num GADE_Difficulty_in_life  SWL1_Ideal_life  \
# 0                            0    Not difficult at all                3
# 1                            1      Somewhat difficult                3
# 2                            0    Not difficult at all                2
# 3                            0    Not difficult at all                2
# 4                            2          Very difficult                2
#
#    SWL2_Excellent_conditions  SWL3_Satisfied_with_life  SWL4_Met_wants  \
# 0                          5                         5               5
# 1                          5                         2               5
# 2                          6                         5               2
# 3                          5                         5               3
# 4                          2                         4               5
#
#    SWL5_Change_nothing    Game                 Platform  Hours  \
# 0                    5  Skyrim  Console (PS, Xbox, ...)     15
# 1                    1   Other                       PC      8
# 2                    2   Other                       PC      0
# 3                    2   Other                       PC     20
# 4                    1   Other  Console (PS, Xbox, ...)     20
#
#          Earnings    Why_play   League  Non_game_hours  SPIN1_Fear_authority  \
# 0  I play for fun  having fun  unknown               0                     1
# 1  I play for fun  having fun  unknown               2                     2
# 2  I play for fun  having fun  unknown               0                     1
# 3  I play for fun   improving  unknown               5                     2
# 4  I play for fun  having fun  unknown               1                     2
#
#    SPIN2_Distress_blushing  SPIN3_Fear_social_events  SPIN4_Avoid_strangers  \
# 0                        0                         0                      1
# 1                        1                         1                      3
# 2                        0                         1                      2
# 3                        0                         0                      1
# 4                        0                         0                      0
#
#    SPIN5_Fear_criticism  SPIN6_Avoid_embarrassment  SPIN7_Distress_sweating  \
# 0                     0                          0                        1
# 1                     2                          3                        1
# 2                     3                          4                        2
# 3                     3                          0                        0
# 4                     1                          0                        0
#
#    SPIN8_Avoid_parties  SPIN9_Avoid_attention  SPIN10_Fear_talking_strangers  \
# 0                    0                      0                              0
# 1                    3                      4                              0
# 2                    1                      0                              1
# 3                    0                      0                              0
# 4                    4                      2                              0
#
#    SPIN11_Avoid_giving_speeches  SPIN12_Avoid_criticism  \
# 0                             0                       0
# 1                             3                       0
# 2                             1                       3
# 3                             1                       3
# 4                             1                       0
#
#    SPIN13_Distress_heart  SPIN14_Fear_observation  SPIN15_Fear_embarrassment  \
# 0                      0                        1                          0
# 1                      1                        3                          3
# 2                      0                        2                          4
# 3                      0                        0                          1
# 4                      0                        0                          0
#
#    SPIN16_Avoid_authority  SPIN17_Distress_trembling  Narcissism  Gender  \
# 0                       1                          0         1.0    Male
# 1                       1                          2         1.0    Male
# 2                       4                          2         4.0  Female
# 3                       0                          0         2.0    Male
# 4                       3                          0         1.0    Male
#
#   Age_binned  Age                       Work  \
# 0      23-25   25  Unemployed / between jobs
# 1        26+   41  Unemployed / between jobs
# 2        26+   32                   Employed
# 3        26+   28                   Employed
# 4      18-19   19                   Employed
#
#                                 Degree Reference  \
# 0             Bachelor (or equivalent)    Reddit
# 1             Bachelor (or equivalent)    Reddit
# 2             Bachelor (or equivalent)    Reddit
# 3             Bachelor (or equivalent)    Reddit
# 4  High school diploma (or equivalent)    Reddit
#
#                                           Play_style  Accept  GAD_Total  \
# 0                                       Singleplayer  Accept          1
# 1              Multiplayer - online - with strangers  Accept          8
# 2                                       Singleplayer  Accept          8
# 3  Multiplayer - online - with online acquaintanc...  Accept          0
# 4              Multiplayer - online - with strangers  Accept         14
#
#    SWL_Total  SPIN_Total Residence_ISO3 Birthplace_ISO3
# 0         23           5            USA             USA
# 1         16          33            USA             USA
# 2         17          31            DEU             DEU
# 3         17          11            USA             USA
# 4         14          13            KOR             USA

# %%
df['Age_binned'].value_counts()
# Out:
# Age_binned
# 18-19    3624
# 20-22    2417
# 23-25    2173
# 26+       744
# Name: count, dtype: int64

# %%
x = np.arange(4)
age_GAD_scores = df.groupby('Age_binned')['GAD_Total'].mean() 
age_SWL_scores = df.groupby('Age_binned')['SWL_Total'].mean()
age_SPIN_scores = df.groupby('Age_binned')['SPIN_Total'].mean()
width=.2 

plt.bar(x-0.2, age_GAD_scores, width, color='royalblue')
plt.bar(x, age_SWL_scores, width, color='turquoise')
plt.bar(x+0.2, age_SPIN_scores, width, color='limegreen')

plt.xticks(x, ['18-19', '20-22','23-25', '26+'])
plt.xlabel('Participant Age (binned)')
plt.ylabel('Average Score')
plt.legend(['GAD', 'SWL', 'SPIN'])
plt.title('Age and Average Test Scores')

# Save figure as image
# plt.savefig('plots/Age_scores_grouped_bar_chart.png')

plt.show()

# %% [markdown]
# ## Scatterplots
# - How does age correspond with hours played each week?
# - Scatterplot was chosen to quickly see a visual representation and skew. In hindsight, houwever, this is not the best plot to use for this analysis.
# - As suspected, younger participants report more gaming hours each week.
#
# In hindsight, this was not the best type of chart for this analysis, though you can see a downward trend of hours played as age increases.

# %%
plt.figure(figsize=(10,6))
plt.scatter(
    df['Age'],
    df['Hours'],
    color='royalblue',
    s = 5
)

plt.xlabel('Age of participant')
plt.ylabel('Hours played per week')
plt.title('Relationship between age and time spent gaming per week')

# Save figure as image
# plt.savefig('plots/Age_hours_scatterplot.png')

plt.show()

# %% [markdown]
# ## Heat Maps
# - How do the numeric values correlate across the dataframe?
# - Is there a significant relationship between the answers to each test and their score?

# %% [markdown]
# ### Heat map of all data

# %%
plt.figure(figsize=(12, 6))

numeric_df = df.select_dtypes(include=[np.number])
corr = numeric_df.corr()

im = plt.imshow(corr, vmin=-1, vmax=1, cmap="coolwarm") # customization
plt.colorbar(im, label='Pearson Correllation')

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45, ha='right')
plt.yticks(range(len(corr.columns)), corr.columns)

plt.show()

# %% [markdown]
# #### Heat map GAD comparison
# Resource: https://stackoverflow.com/questions/21285380/find-column-whose-name-contains-a-specific-string

# %%
numeric_GAD_df = numeric_df.filter(regex='GAD')
numeric_GAD_df.head()
# Out:
#    GAD1_Feeling_nervous  GAD2_Cant_stop_worrying  GAD3_Worrying_too_much  \
# 0                     0                        0                       0
# 1                     1                        2                       2
# 2                     0                        2                       2
# 3                     0                        0                       0
# 4                     2                        1                       2
#
#    GAD4_Trouble_relaxing  GAD5_Restless  GAD6_Easily_annoyed  \
# 0                      0              1                    0
# 1                      2              0                    1
# 2                      0              0                    3
# 3                      0              0                    0
# 4                      2              2                    3
#
#    GAD7_Feeling_afraid  GADE_Difficulty_in_life_num  GAD_Total
# 0                    0                            0          1
# 1                    0                            1          8
# 2                    1                            0          8
# 3                    0                            0          0
# 4                    2                            2         14

# %%
plt.figure(figsize=(12, 6))

corr = numeric_GAD_df.corr()

im = plt.imshow(corr, vmin=-1, vmax=1, cmap="coolwarm") # customization
plt.colorbar(im, label='Pearson Correllation')

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45, ha='right')
plt.yticks(range(len(corr.columns)), corr.columns)

plt.show()

# %% [markdown]
# #### Heat map SWL comparison

# %%
numeric_SWL_df = numeric_df.filter(regex='SWL')
numeric_SWL_df.head()
# Out:
#    SWL1_Ideal_life  SWL2_Excellent_conditions  SWL3_Satisfied_with_life  \
# 0                3                          5                         5
# 1                3                          5                         2
# 2                2                          6                         5
# 3                2                          5                         5
# 4                2                          2                         4
#
#    SWL4_Met_wants  SWL5_Change_nothing  SWL_Total
# 0               5                    5         23
# 1               5                    1         16
# 2               2                    2         17
# 3               3                    2         17
# 4               5                    1         14

# %%
plt.figure(figsize=(12, 6))

corr = numeric_SWL_df.corr()

im = plt.imshow(corr, vmin=-1, vmax=1, cmap="coolwarm") # customization
plt.colorbar(im, label='Pearson Correllation')

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45, ha='right')
plt.yticks(range(len(corr.columns)), corr.columns)

plt.show()

# %% [markdown]
# #### Heat map SPIN comparison

# %%
numeric_SPIN_df = numeric_df.filter(regex='SPIN')
numeric_SPIN_df.head()
# Out:
#    SPIN1_Fear_authority  SPIN2_Distress_blushing  SPIN3_Fear_social_events  \
# 0                     1                        0                         0
# 1                     2                        1                         1
# 2                     1                        0                         1
# 3                     2                        0                         0
# 4                     2                        0                         0
#
#    SPIN4_Avoid_strangers  SPIN5_Fear_criticism  SPIN6_Avoid_embarrassment  \
# 0                      1                     0                          0
# 1                      3                     2                          3
# 2                      2                     3                          4
# 3                      1                     3                          0
# 4                      0                     1                          0
#
#    SPIN7_Distress_sweating  SPIN8_Avoid_parties  SPIN9_Avoid_attention  \
# 0                        1                    0                      0
# 1                        1                    3                      4
# 2                        2                    1                      0
# 3                        0                    0                      0
# 4                        0                    4                      2
#
#    SPIN10_Fear_talking_strangers  SPIN11_Avoid_giving_speeches  \
# 0                              0                             0
# 1                              0                             3
# 2                              1                             1
# 3                              0                             1
# 4                              0                             1
#
#    SPIN12_Avoid_criticism  SPIN13_Distress_heart  SPIN14_Fear_observation  \
# 0                       0                      0                        1
# 1                       0                      1                        3
# 2                       3                      0                        2
# 3                       3                      0                        0
# 4                       0                      0                        0
#
#    SPIN15_Fear_embarrassment  SPIN16_Avoid_authority  \
# 0                          0                       1
# 1                          3                       1
# 2                          4                       4
# 3                          1                       0
# 4                          0                       3
#
#    SPIN17_Distress_trembling  SPIN_Total
# 0                          0           5
# 1                          2          33
# 2                          2          31
# 3                          0          11
# 4                          0          13

# %%
plt.figure(figsize=(12, 6))

corr = numeric_SPIN_df.corr()

im = plt.imshow(corr, vmin=-1, vmax=1, cmap="coolwarm") # customization
plt.colorbar(im, label='Pearson Correllation')

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45, ha='right')
plt.yticks(range(len(corr.columns)), corr.columns)

plt.show()

# %% [markdown]
# ## SCATTERPLOTS
# How does hours played per week correlate with test scores?

# %%
# df.head()

# %%
plt.scatter(df["Age"], df["GAD_Total"])

plt.xlabel('Age', fontsize=14)
plt.ylabel('Test Score', fontsize=14)
plt.title('GAD Scores by Age', fontsize=16)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.scatter(df["Age"], df["GAD_Total"])
#       2
#       3 plt.xlabel('Age', fontsize=14)
#       4 plt.ylabel('Test Score', fontsize=14)
#
# NameError: name 'df' is not defined

# %%
plt.scatter(df["Age"], df["SWL_Total"])

plt.xlabel('Age', fontsize=14)
plt.ylabel('Test Score', fontsize=14)
plt.title('SWL Scores by Age', fontsize=16)

plt.show()

# %%
plt.scatter(df["Hours"], df["SPIN_Total"])

plt.xlabel('Age', fontsize=14)
plt.ylabel('Test Score', fontsize=14)
plt.title('SPIN Scores by Hours', fontsize=16)

plt.show()
