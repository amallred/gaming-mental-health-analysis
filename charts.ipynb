# %% [markdown]
# ## Import Data & Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.set_option('display.max_columns', None)

df = pd.read_csv('data/clean_data.csv')
df.head()
# Out:
#    Unnamed: 0  S. No.        Date  GAD1_Feeling_nervous  \
# 0           0       1  2015-02-17                     0
# 1           1       2  2015-02-17                     1
# 2           2       3  2015-02-17                     0
# 3           3       4  2015-02-17                     0
# 4           4       5  2015-02-17                     2
#
#    GAD2_Cant_stop_worrying  GAD3_Worrying_too_much  GAD4_Trouble_relaxing  \
# 0                        0                       0                      0
# 1                        2                       2                      2
# 2                        2                       2                      0
# 3                        0                       0                      0
# 4                        1                       2                      2
#
#    GAD5_Restless  GAD6_Easily_annoyed  GAD7_Feeling_afraid  \
# 0              1                    0                    0
# 1              0                    1                    0
# 2              0                    3                    1
# 3              0                    0                    0
# 4              2                    3                    2
#
#    GADE_Difficulty_in_life_num GADE_Difficulty_in_life  SWL1_Ideal_life  \
# 0                            0    Not difficult at all                3
# 1                            1      Somewhat difficult                3
# 2                            0    Not difficult at all                2
# 3                            0    Not difficult at all                2
# 4                            2          Very difficult                2
#
#    SWL2_Excellent_conditions  SWL3_Satisfied_with_life  SWL4_Met_wants  \
# 0                          5                         5               5
# 1                          5                         2               5
# 2                          6                         5               2
# 3                          5                         5               3
# 4                          2                         4               5
#
#    SWL5_Change_nothing    Game                 Platform  Hours  \
# 0                    5  Skyrim  Console (PS, Xbox, ...)     15
# 1                    1   Other                       PC      8
# 2                    2   Other                       PC      0
# 3                    2   Other                       PC     20
# 4                    1   Other  Console (PS, Xbox, ...)     20
#
#          Earnings    Why_play   League  Non_game_hours  SPIN1_Fear_authority  \
# 0  I play for fun  having fun  unknown               0                     1
# 1  I play for fun  having fun  unknown               2                     2
# 2  I play for fun  having fun  unknown               0                     1
# 3  I play for fun   improving  unknown               5                     2
# 4  I play for fun  having fun  unknown               1                     2
#
#    SPIN2_Distress_blushing  SPIN3_Fear_social_events  SPIN4_Avoid_strangers  \
# 0                        0                         0                      1
# 1                        1                         1                      3
# 2                        0                         1                      2
# 3                        0                         0                      1
# 4                        0                         0                      0
#
#    SPIN5_Fear_criticism  SPIN6_Avoid_embarrassment  SPIN7_Distress_sweating  \
# 0                     0                          0                        1
# 1                     2                          3                        1
# 2                     3                          4                        2
# 3                     3                          0                        0
# 4                     1                          0                        0
#
#    SPIN8_Avoid_parties  SPIN9_Avoid_attention  SPIN10_Fear_talking_strangers  \
# 0                    0                      0                              0
# 1                    3                      4                              0
# 2                    1                      0                              1
# 3                    0                      0                              0
# 4                    4                      2                              0
#
#    SPIN11_Avoid_giving_speeches  SPIN12_Avoid_criticism  \
# 0                             0                       0
# 1                             3                       0
# 2                             1                       3
# 3                             1                       3
# 4                             1                       0
#
#    SPIN13_Distress_heart  SPIN14_Fear_observation  SPIN15_Fear_embarrassment  \
# 0                      0                        1                          0
# 1                      1                        3                          3
# 2                      0                        2                          4
# 3                      0                        0                          1
# 4                      0                        0                          0
#
#    SPIN16_Avoid_authority  SPIN17_Distress_trembling  Narcissism  Gender  Age  \
# 0                       1                          0         1.0    Male   25
# 1                       1                          2         1.0    Male   41
# 2                       4                          2         4.0  Female   32
# 3                       0                          0         2.0    Male   28
# 4                       3                          0         1.0    Male   19
#
#   Age_binned                       Work                               Degree  \
# 0      23-25  Unemployed / between jobs             Bachelor (or equivalent)
# 1        26+  Unemployed / between jobs             Bachelor (or equivalent)
# 2        26+                   Employed             Bachelor (or equivalent)
# 3        26+                   Employed             Bachelor (or equivalent)
# 4      18-19                   Employed  High school diploma (or equivalent)
#
#   Reference                                         Play_style  Accept  \
# 0    Reddit                                       Singleplayer  Accept
# 1    Reddit              Multiplayer - online - with strangers  Accept
# 2    Reddit                                       Singleplayer  Accept
# 3    Reddit  Multiplayer - online - with online acquaintanc...  Accept
# 4    Reddit              Multiplayer - online - with strangers  Accept
#
#    GAD_Total  SWL_Total  SPIN_Total Residence_ISO3 Birthplace_ISO3
# 0          1         23           5            USA             USA
# 1          8         16          33            USA             USA
# 2          8         17          31            DEU             DEU
# 3          0         17          11            USA             USA
# 4         14         14          13            KOR             USA

# %% [markdown]
# ## Charts for analysis
# - QUESTIONS:
#   - Stacked bar (test scores / sex) : Does reported sex impact test scores?
#   - Is there a correlation between hours played and high test scores?
#   - Distribution of average weekly hours spent gaming (histogram maybe not best)

# %% [markdown]
# ### HISTOGRAMS

# %%
# HISTOGRAM
# How did users score on the Generalized Anxiety Disorder (GAD) test?

plt.figure(figsize=(10,6))
plt.hist(
    df['GAD_Total'],
    bins=15,
    edgecolor='white'
)

plt.xlabel("Generalized Anxiety Disorder Assessment Score (0-21)")
plt.ylabel("Number of Survey Pariticpants")
plt.title("Distribution of GAD Scores", fontsize=16, pad=20)


# || ADD EXPLANATION OF SCORES ||


plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(
    df['SWL_Total'],
    bins=17,
    edgecolor='white'
)

plt.xlabel("Satisfaction with Life Assessment (0-35)")
plt.ylabel("Number of Survey Pariticpants")
plt.title("Distribution of SWL Scores", fontsize=16, pad=20)


# || ADD EXPLANATION OF SCORES ||


plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(
    df['SPIN_Total'],
    bins=25,
    edgecolor='white'
)

plt.xlabel("Social Phobia Inventory (SPIN) Assessment (0-35)")
plt.ylabel("Number of Survey Pariticpants")
plt.title("Distribution of SPIN Scores", fontsize=16, pad=20)


# || ADD EXPLANATION OF SCORES ||


plt.show()
